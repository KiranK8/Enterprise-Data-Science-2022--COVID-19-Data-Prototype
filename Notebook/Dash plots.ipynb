# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import plotly.express as px
import plotly.graph_objects as go

# %%
df_test=pd.read_csv('Documents/ads_covid-19/data/processed/Covid_full_data.csv',sep=';')
df_test.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# ...

# %%
country_list=['Italy',
              'India',
              'Spain',
              'Germany',
              'United States',
             ]

# %%
df_test2  = pd.DataFrame()

# %%
for each in country_list:
    df_test2= df_test2.append(df_test[df_test['location']==each])
# Out:
# C:\Users\kiran\AppData\Local\Temp\ipykernel_13920\433529568.py:2: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\kiran\AppData\Local\Temp\ipykernel_13920\433529568.py:2: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\kiran\AppData\Local\Temp\ipykernel_13920\433529568.py:2: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\kiran\AppData\Local\Temp\ipykernel_13920\433529568.py:2: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\kiran\AppData\Local\Temp\ipykernel_13920\433529568.py:2: FutureWarning:
#
# ...

# %%
df_test2=df_test2.reset_index(drop=True)

# %%
df_test2
# Out:
#      iso_code      continent       location        date  total_cases  \
# 0         ITA         Europe          Italy  2020-01-31          2.0
# 1         ITA         Europe          Italy  2020-02-01          2.0
# 2         ITA         Europe          Italy  2020-02-02          2.0
# 3         ITA         Europe          Italy  2020-02-03          2.0
# 4         ITA         Europe          Italy  2020-02-04          2.0
# ...       ...            ...            ...         ...          ...
# 4398      USA  North America  United States  2022-06-22   86636306.0
# 4399      USA  North America  United States  2022-06-23   86757621.0
# 4400      USA  North America  United States  2022-06-24   86909716.0
# 4401      USA  North America  United States  2022-06-25   86949088.0
# 4402      USA  North America  United States  2022-06-26   86967639.0
#
#       new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0           2.0                 NaN           NaN         NaN
# ...

# %%
sel_countries = df_test2[df_test2['location']=='India']
sel_countries.head()
# Out:
#     iso_code continent location        date  total_cases  new_cases  \
# 878      IND      Asia    India  2020-01-30          1.0        1.0
# 879      IND      Asia    India  2020-01-31          1.0        0.0
# 880      IND      Asia    India  2020-02-01          1.0        0.0
# 881      IND      Asia    India  2020-02-02          2.0        1.0
# 882      IND      Asia    India  2020-02-03          3.0        1.0
#
#      new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 878                 NaN           NaN         NaN                  NaN  ...
# 879                 NaN           NaN         NaN                  NaN  ...
# 880                 NaN           NaN         NaN                  NaN  ...
# 881                 NaN           NaN         NaN                  NaN  ...
# 882                 NaN           NaN         NaN                  NaN  ...
#
#      handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# ...

# %% [markdown]
# # The relative cases overtime of Covid infectors for 5 Countries

# %%
import dash
dash.__version__
from dash import dcc
from dash import html

app = dash.Dash()
app.layout = html.Div([
    
    html.Label('Multi-Select Country'),
    
       dcc.Dropdown(
        id='country_drop_down',
        options=[{'label': i, 'value': i}
                for i in df_test2['location'].unique() ],
           
        value=['India','Germany'], # which are pre-selected
        multi=True
    ),   
        
    dcc.Graph(id='main_window_slope', figure={})
])

# %%
from dash.dependencies import Input, Output

@app.callback(
    Output('main_window_slope', 'figure'),
    [Input('country_drop_down', 'value')])
def update_graph(option):
    print(option)
    print(type(option))
    
    if type(option)!=str:
        dff = df_test2[df_test2['location'].isin(option) ]
    else:
        dff = df_test2[df_test2['location']==option]
        

    # dff = df_test2[df_test2["location"] == option]

    # Plotly Express
    
    fig = px.line(dff, x='date', y='Relative_cases',color='location',title='Covid Relative Cases Over Time')
    
    return fig

# %%
app.run_server(debug=True, use_reloader=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
# ['India', 'Germany']
# <class 'list'>
# ['India', 'Germany', 'Spain']
# <class 'list'>
# ['India', 'Germany', 'Spain', 'United States']
# <class 'list'>
# ['India', 'Germany', 'Spain', 'United States', 'Italy']
# <class 'list'>

# %% [markdown]
# # The relative cases overtime of Covid infectors for all Countries

# %%
import dash
dash.__version__
from dash import dcc
from dash import html

app = dash.Dash()
app.layout = html.Div([
    
    html.Label('Multi-Select Country'),
    
       dcc.Dropdown(
        id='country_drop_down',
        options=[{'label': i, 'value': i}
                for i in df_test['location'].unique() ],
           
        value=['India','Germany'], # which are pre-selected
        multi=True
    ),   
        
    dcc.Graph(id='main_window_slope', figure={})
])

# %%
from dash.dependencies import Input, Output

@app.callback(
    Output('main_window_slope', 'figure'),
    [Input('country_drop_down', 'value')])
def update_graph(option):
    print(option)
    print(type(option))
    
    if type(option)!=str:
        dff = df_test[df_test['location'].isin(option) ]
    else:
        dff = df_test[df_test['location']==option]
        

    # dff = df_test2[df_test2["location"] == option]

    # Plotly Express
    
    fig = px.line(dff, x='date', y='Relative_cases',color='location',title='Covid Relative Cases Over Time')
    
    return fig

# %%
app.run_server(debug=True, use_reloader=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on

# %% [markdown]
# # The vaccination rate over time for all Countries

# %%
df_test2 = df_test[(df_test['date']>'2021-01-01')]

# %%
import dash
dash.__version__
from dash import dcc
from dash import html

app = dash.Dash()
app.layout = html.Div([
    
    html.Label('Multi-Select Country'),
    
       dcc.Dropdown(
        id='country_drop_down',
        options=[{'label': i, 'value': i}
                for i in df_test2['location'].unique() ],
           
        value=['India','Germany'], # which are pre-selected
        multi=True
    ),   
        
    dcc.Graph(id='main_window_slope', figure={})
])

# %%
from dash.dependencies import Input, Output

@app.callback(
    Output('main_window_slope', 'figure'),
    [Input('country_drop_down', 'value')])
def update_graph(option):
    print(option)
    print(type(option))
    
    if type(option)!=str:
        dff = df_test2[df_test2['location'].isin(option) ]
    else:
        dff = df_test2[df_test2['location']==option]
        

    # dff = df_test2[df_test2["location"] == option]

    # Plotly Express
    
    fig = px.line(dff, x='date', y='Vaccination_Rate',color='location',title='Vaccination Rate Over Time')
    
    return fig

# %%
app.run_server(debug=True, use_reloader=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
# ['India', 'Germany']
# <class 'list'>
# ['India', 'Germany', 'Angola']
# <class 'list'>
# ['India', 'Germany', 'Angola', 'Algeria']
# <class 'list'>
# ['India', 'Germany', 'Angola', 'Algeria', 'Burkina Faso']
# <class 'list'>
# ['India', 'Germany', 'Angola', 'Algeria', 'Burkina Faso', 'Peru']
# <class 'list'>
# ['India', 'Germany', 'Angola', 'Algeria', 'Burkina Faso', 'Peru', 'United Arab Emirates']
# ...
