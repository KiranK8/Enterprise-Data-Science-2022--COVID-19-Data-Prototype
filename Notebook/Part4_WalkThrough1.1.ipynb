# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import pandas as pd
import numpy as np



# %matplotlib inline
mpl.rcParams['figure.figsize'] = (16, 10)
pd.set_option('display.max_rows', 500)

import plotly.graph_objects as go

# %%
df_test=pd.read_csv('Documents/ads_covid-19/data/processed/Covid_full_data.csv',sep=';')
df_test.tail()
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 202875      ZWE    Africa  Zimbabwe  2022-07-17     256083.0        0.0
# 202876      ZWE    Africa  Zimbabwe  2022-07-18     256083.0        0.0
# 202877      ZWE    Africa  Zimbabwe  2022-07-19     256187.0      104.0
# 202878      ZWE    Africa  Zimbabwe  2022-07-20     256187.0        0.0
# 202879      ZWE    Africa  Zimbabwe  2022-07-21     256217.0       30.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 202875              20.571        5566.0         0.0                0.286
# 202876              18.571        5566.0         0.0                0.143
# 202877              29.429        5568.0         2.0                0.429
# 202878              29.429        5568.0         0.0                0.429
# 202879              24.286        5570.0         2.0                0.571
#
#         ...  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
col_list = list(df_test.columns)              #interchange the column continent and date
x, y = col_list.index('date'), col_list.index('iso_code')
col_list[y], col_list[x] = col_list[x], col_list[y]
df_test = df_test[col_list]

# %%
col_list = list(df_test.columns)              #interchange the column continent and date
x, y = col_list.index('continent'), col_list.index('location')
col_list[y], col_list[x] = col_list[x], col_list[y]
df_test = df_test[col_list]

# %%
col_list = list(df_test.columns)              #interchange the column continent and date
x, y = col_list.index('continent'), col_list.index('total_cases')
col_list[y], col_list[x] = col_list[x], col_list[y]
df_test = df_test[col_list]

# %%
df_test = df_test[df_test['location'] != 'Niue']
df_test = df_test[df_test['location'] != 'North Korea']
df_test = df_test[df_test['location'] != 'Northern Cyprus']
df_test = df_test[df_test['location'] != 'Northern Mariana Islands']
df_test = df_test[df_test['location'] != 'Palau']
df_test = df_test[df_test['location'] != 'Pitcairn']
df_test = df_test[df_test['location'] != 'Togo']
df_test = df_test[df_test['location'] != 'Tokelau']
df_test = df_test[df_test['location'] != 'Turkmenistan']
df_test = df_test[df_test['location'] != 'Tuvalu']
df_test = df_test[df_test['location'] != 'Western Sahara']
df_test = df_test[df_test['location'] != 'Cook Islands']
df_test = df_test[df_test['location'] != 'Guam']
df_test = df_test[df_test['location'] != 'Guernsey']
df_test = df_test[df_test['location'] != 'International']
df_test = df_test[df_test['location'] != 'Isle of Man']
df_test = df_test[df_test['location'] != 'Jersey']
df_test = df_test[df_test['location'] != 'Jordan']
df_test = df_test[df_test['location'] != 'Nauru']
df_test = df_test[df_test['location'] != 'New Caledonia']
df_test = df_test[df_test['location'] != 'Puerto Rico']
df_test = df_test[df_test['location'] != 'Romania']
df_test = df_test[df_test['location'] != 'Sint Maarten (Dutch part)']
df_test = df_test[df_test['location'] != 'Solomon Islands']
df_test = df_test[df_test['location'] != 'Tonga']
df_test = df_test[df_test['location'] != 'Turkey']
df_test = df_test[df_test['location'] != 'United States Virgin Islands']
df_test = df_test[df_test['location'] != 'Kiribati']
df_test = df_test[df_test['location'] != 'Micronesia (country)']
df_test = df_test[df_test['location'] != 'Moldova']

# %%
country_list=df_test['location']

# %%
country_list = country_list.drop_duplicates()
country_list
# Out:
# 0                              Afghanistan
# 879                                 Africa
# 1769                               Albania
# 2647                               Algeria
# 3525                               Andorra
# 4397                                Angola
# 5251                              Anguilla
# 6097                   Antigua and Barbuda
# 6958                             Argentina
# 7891                               Armenia
# 8791                                 Aruba
# 9652                                  Asia
# 10564                            Australia
# 11472                              Austria
# 12350                           Azerbaijan
# 13223                              Bahamas
# 14081                              Bahrain
# 14960                           Bangladesh
# 15826                             Barbados
# 16683                              Belarus
# 17558                              Belgium
# 18457                               Belize
# ...

# %%
df_test = df_test[(df_test['date']>'2021-01-01') & (df_test['date']<'2022-07-21')]

# %%
df_test=df_test.iloc[:,:3:]
df_test
# Out:
#               date     location  total_cases
# 313     2021-01-02  Afghanistan      52586.0
# 314     2021-01-03  Afghanistan      52709.0
# 315     2021-01-04  Afghanistan      52909.0
# 316     2021-01-05  Afghanistan      53011.0
# 317     2021-01-06  Afghanistan      53105.0
# ...            ...          ...          ...
# 202874  2022-07-16     Zimbabwe     256083.0
# 202875  2022-07-17     Zimbabwe     256083.0
# 202876  2022-07-18     Zimbabwe     256083.0
# 202877  2022-07-19     Zimbabwe     256187.0
# 202878  2022-07-20     Zimbabwe     256187.0
#
# [120910 rows x 3 columns]

# %%
df_test.to_csv('Documents/ads_covid-19/data/processed/DataForDoublingRate.csv',sep=';',index=False)

# %%
b_date=df_test['location'] =='Germany'

# %%
b_date=df_test[b_date]

# %%
time_idx=b_date['date']

# %%
df_plot = pd.DataFrame({
    'date':time_idx})

# %%
df_plot=df_plot.reset_index(drop=True) 
df_plot
# Out:
#            date
# 0    2021-01-02
# 1    2021-01-03
# 2    2021-01-04
# 3    2021-01-05
# 4    2021-01-06
# ..          ...
# 560  2022-07-16
# 561  2022-07-17
# 562  2022-07-18
# 563  2022-07-19
# 564  2022-07-20
#
# [565 rows x 1 columns]

# %%
for each in country_list:
    df_plot[each] = np.array(df_test[df_test['location']==each].iloc[:,2:3:])
df_plot
# Out:
# C:\Users\kiran\AppData\Local\Temp\ipykernel_19228\1639334639.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_plot[each] = np.array(df_test[df_test['location']==each].iloc[:,2:3:])
# C:\Users\kiran\AppData\Local\Temp\ipykernel_19228\1639334639.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_plot[each] = np.array(df_test[df_test['location']==each].iloc[:,2:3:])
# ...

# %%
df_plot.to_csv('Documents/ads_covid-19/data/processed/CompleteProcessedData.csv',sep=';',index=False)
